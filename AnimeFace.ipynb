# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from fastai import *
from fastai.vision import *

# %%
path = Path('/home/david/Documents/animeface')

# %%
bs = 512
size=128

# %%
np.random.seed(42)
src = ImageList.from_folder(path/'thumb').split_by_rand_pct(0.2).label_from_folder()
tfms = get_transforms()

# %%
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)

# %%
data.show_batch()

# %%
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>6.413908</td>
#       <td>4.046963</td>
#       <td>0.183920</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.709628</td>
#       <td>2.090489</td>
#       <td>0.510352</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.516872</td>
#       <td>1.590489</td>
#       <td>0.600759</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.767400</td>
#       <td>1.423937</td>
#       <td>0.644582</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.308426</td>
#       <td>1.399062</td>
#       <td>0.650794</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.923484</td>
#       <td>3.283534</td>
#       <td>0.288130</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.809994</td>
#       <td>1.713678</td>
#       <td>0.576950</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.571231</td>
#       <td>1.315145</td>
#       <td>0.659075</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.891061</td>
#       <td>1.164322</td>
#       <td>0.699103</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.542253</td>
#       <td>1.143960</td>
#       <td>0.704969</td>
#       <td>00:11</td>
#     </tr>
#   </tbody>
# </table>

# %%
# plot_lrgc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.273921</td>
#       <td>2.849440</td>
#       <td>0.379917</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.901235</td>
#       <td>1.512648</td>
#       <td>0.621808</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.868720</td>
#       <td>1.164672</td>
#       <td>0.705659</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.398489</td>
#       <td>1.028724</td>
#       <td>0.734300</td>
#       <td>00:09</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.141330</td>
#       <td>1.003731</td>
#       <td>0.745342</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.375361</td>
#       <td>2.564387</td>
#       <td>0.417874</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.304950</td>
#       <td>1.413876</td>
#       <td>0.629055</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.589350</td>
#       <td>1.055659</td>
#       <td>0.716356</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.205176</td>
#       <td>0.905246</td>
#       <td>0.759144</td>
#       <td>00:10</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.010996</td>
#       <td>0.876362</td>
#       <td>0.769841</td>
#       <td>00:10</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.643202</td>
#       <td>2.311111</td>
#       <td>0.464458</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.173089</td>
#       <td>1.308449</td>
#       <td>0.652174</td>
#       <td>00:11</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.529607</td>
#       <td>0.977415</td>
#       <td>0.740166</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.161595</td>
#       <td>0.824372</td>
#       <td>0.782264</td>
#       <td>00:12</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.967379</td>
#       <td>0.789927</td>
#       <td>0.797446</td>
#       <td>00:12</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)
learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.333984</td>
#       <td>2.322748</td>
#       <td>0.442374</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.379395</td>
#       <td>1.332936</td>
#       <td>0.645618</td>
#       <td>00:16</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>1.679827</td>
#       <td>0.982115</td>
#       <td>0.735680</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.259193</td>
#       <td>0.796049</td>
#       <td>0.790545</td>
#       <td>00:17</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.056584</td>
#       <td>0.766959</td>
#       <td>0.798137</td>
#       <td>00:17</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)

learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>3.502414</td>
#       <td>2.494371</td>
#       <td>0.410973</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>2.515600</td>
#       <td>1.534126</td>
#       <td>0.611456</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>2.017991</td>
#       <td>1.164624</td>
#       <td>0.700483</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>1.616544</td>
#       <td>0.911246</td>
#       <td>0.766046</td>
#       <td>00:28</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>1.344311</td>
#       <td>0.868728</td>
#       <td>0.782609</td>
#       <td>00:28</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)

learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>4.266292</td>
#       <td>3.247691</td>
#       <td>0.280538</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>3.543936</td>
#       <td>2.508898</td>
#       <td>0.418910</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>3.066371</td>
#       <td>1.874626</td>
#       <td>0.558661</td>
#       <td>00:55</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>2.598093</td>
#       <td>1.543862</td>
#       <td>0.635266</td>
#       <td>00:56</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>2.388465</td>
#       <td>1.448540</td>
#       <td>0.670462</td>
#       <td>00:57</td>
#     </tr>
#   </tbody>
# </table>

# %%
gc.collect()
learn = None
bs = bs//2
data = src.transform(tfms, size=size).databunch(bs=bs).normalize(imagenet_stats)
learn = cnn_learner(data, models.resnet34, metrics=accuracy, callback_fns=ShowGraph)

learn.fit_one_cycle(5)
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>accuracy</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>5.104828</td>
#       <td>4.693387</td>
#       <td>0.068323</td>
#       <td>01:56</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>4.838840</td>
#       <td>4.477030</td>
#       <td>0.101104</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>4.785437</td>
#       <td>4.409585</td>
#       <td>0.105935</td>
#       <td>01:50</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>4.667289</td>
#       <td>4.344494</td>
#       <td>0.139061</td>
#       <td>01:49</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>4.498869</td>
#       <td>4.372125</td>
#       <td>0.142857</td>
#       <td>01:49</td>
#     </tr>
#   </tbody>
# </table>

# %%
bs
# Out:
# 2
